# %% [markdown]
# # Extract Frames from Videos and save it in a folder with the emotion label
# This file also saves the MainDataSaved.csv file which contains the path to the frames and the emotion label

# %%
import pandas as pd
from collections import Counter
import numpy as np
import ast
import matplotlib.pyplot as plt
import csv
import os
import cv2

# %% [markdown]
# ## Read Annotations File

# %%
videos_folder = 'Videos' # change the folder name to the folder where the videos are stored
outputs_path ='ExtractedData'

typeEmotions=['Anger','Disgust','Fear','Happy','Sad','Surprise','Neutral']

annotations = pd.read_csv("./Annotations/annotations.csv", header=None)
annotations.columns = ["video_tag", "clip_id", "label", "frame_no", "x", "y", "w", "h", "person_id"]

# %%
uniqueVideos= annotations['video_tag'].unique()

# %%
#remove 'No annotation' from the label column, the column is a list of values and selecting the most frequent annotation out of the 3 annotations
annotations['label'] = annotations['label'].apply(ast.literal_eval)

#remove 'No annotation' from the label column, the column is a list of values
annotations['label'] = annotations['label'].apply(lambda x: [i for i in x if i != 'No annotation'])

annotations['label'] = annotations['label'].apply(lambda x: [item for sublist in x for item in sublist])
def most_common(lst):
    counts = Counter(lst)
    return max(counts, key=counts.get)
annotations['Unique_labels'] = [most_common(x) for x in annotations['label']]

# %%
annotations
# Out:
#         video_tag  clip_id                  label  frame_no          x  \
# 0     aJKL0ahn1Dk        1  [Happy, Happy, Happy]     19532  41.965200
# 1     aJKL0ahn1Dk        1  [Happy, Happy, Happy]     19538  41.564836
# 2     aJKL0ahn1Dk        1  [Happy, Happy, Happy]     19544  41.164472
# 3     aJKL0ahn1Dk        1  [Happy, Happy, Happy]     19550  40.764108
# 4     aJKL0ahn1Dk        1  [Happy, Happy, Happy]     19556  39.646728
# ...           ...      ...                    ...       ...        ...
# 8082  ngITkMvWuq8        3       [Happy, Neutral]     22471   0.052083
# 8083  ngITkMvWuq8        3       [Happy, Neutral]     22477   0.052083
# 8084  ngITkMvWuq8        3       [Happy, Neutral]     22483   0.052083
# 8085  ngITkMvWuq8        3       [Happy, Neutral]     22489   3.314622
# 8086  ngITkMvWuq8        3         [Happy, Happy]     22495  22.415558
#
#              y          w          h  person_id Unique_labels
# 0     4.873195  44.216991  94.802684          0         Happy
# 1     4.874640  44.216991  94.802684          0         Happy
# 2     4.876086  44.216991  94.802684          0         Happy
# 3     4.877532  44.216991  94.802684          0         Happy
# 4     5.014136  44.216991  94.802684          0         Happy
# ...        ...        ...        ...        ...           ...
# 8082  6.782194  73.680363  93.125213          9         Happy
# 8083  6.782194  72.978506  93.125213          9         Happy
# 8084  6.782194  72.276649  93.125213          9         Happy
# 8085  6.782194  69.153019  93.125213          9         Happy
# 8086  0.142159  70.112590  99.715683          0         Happy
#
# [8087 rows x 10 columns]

# %% [markdown]
# # Save the frames instead of creating video
#
# Saves the frames in a folder names as the video name, clip_id, person_id, and frame_no inside frames folder

# %%
import os
import cv2
import csv

# Assuming annotations, uniqueVideos, typeEmotions, and videos_folder are defined elsewhere
# Save the pathnames and emotions in a CSV file
PATHS = []
EMOTIONS = []

for video in uniqueVideos:
    print("------------------------------Processing video:-------------------------------", video)
    filterVideoData = annotations[annotations['video_tag'] == video]
    uniqueClipID = filterVideoData['clip_id'].unique()
    
    for clipID in uniqueClipID:
        
        print("Processing clip:", clipID)
        filterClipData = filterVideoData[filterVideoData['clip_id'] == clipID]
        uniquePersonID = filterClipData['person_id'].unique()

        for personID in uniquePersonID:
            print("Processing person:", personID)
            filterPersonData = filterClipData[filterClipData['person_id'] == personID]

            for emotion in typeEmotions:
                filterEmotionData = filterPersonData[filterPersonData['Unique_labels'] == emotion]
                print("Processing emotion:", emotion, ", len:", len(filterEmotionData))

                if len(filterEmotionData) > 0:
                    # Split frames into chunks of 18 or less
                    chunks = [filterEmotionData[i:i + 18] for i in range(0, len(filterEmotionData), 18)]

                    for frames in chunks:
                        # Create directory for frames
                        dir = os.getcwd().replace('/Extra', '')
                        pathname = f"{dir}/Frames/{video}_{frames.iloc[0]['clip_id']}_{personID}_{frames.iloc[0]['frame_no']}"
                        PATHS.append(pathname)
                        EMOTIONS.append(emotion)

                        # Check if path already exists
                        if os.path.exists(pathname):
                            print(f"Path {pathname} already exists, skipping.")
                            continue

                        # Create the directory if it doesn't exist
                        os.makedirs(pathname, exist_ok=True)
                        PATHS.append(pathname)
                        EMOTIONS.append(emotion)

                        # Load the video
                        video_path = f'./{videos_folder}/{video}/complete.mp4'
                        video_capture = cv2.VideoCapture(video_path)

                        if not video_capture.isOpened():
                            print(f"Failed to open video: {video_path}")
                            continue

                        # Average width and height for bounding box, if needed
                        maxWidthValue = frames['w'].mean()
                        maxHeightValue = frames['h'].mean()

                        # Process frames
                        for frame_num, x, y, w, h in zip(frames['frame_no'], frames['x'], frames['y'], frames['w'], frames['h']):
                            video_capture.set(cv2.CAP_PROP_POS_FRAMES, float(frame_num))
                            ret, frame = video_capture.read()

                            if not ret:
                                print(f"Frame {frame_num} could not be read from video.")
                                break

                            # Scale bounding box coordinates based on video frame dimensions
                            height, width = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT)), int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
                            x, y = int((float(x) / 100) * width), int((float(y) / 100) * height)
                            w, h = int((float(w) / 100) * width), int((float(h) / 100) * height)

                            # Draw rectangle and crop frame
                            cv2.rectangle(frame, (x, y), (x + w, y + h), (128, 128, 128), 2)
                            cropped_frame = frame[y:y + h, x:x + w]

                            # Save the cropped frame
                            frame_path = f"{pathname}/{frame_num}.jpg"
                            cv2.imwrite(frame_path, cropped_frame)

                        video_capture.release()

# Save the paths and emotions to a CSV file
with open('frame_paths.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Path', 'Emotion'])

    for path, emotion in zip(PATHS, EMOTIONS):
        writer.writerow([path, emotion])
print("Processing completed.")
# Out:
# ------------------------------Processing video:------------------------------- aJKL0ahn1Dk
# Processing clip: 1
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 77
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_0_19532 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_0_19640 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_0_19892 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_0_20054 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_0_20252 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 27
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_1_19700 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_1_20114 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 27
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_2_19772 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_2_20114 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 23
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_3_19952 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_3_20138 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_1_4_20078 already exists, skipping.
# Processing clip: 2
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_2_0_23761 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_2_1_23761 already exists, skipping.
# Processing emotion: Neutral , len: 0
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 14
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_2_2_23857 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_2_2_23761 already exists, skipping.
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_2_3_23761 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 14
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_2_3_23857 already exists, skipping.
# Processing emotion: Neutral , len: 0
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 11
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/aJKL0ahn1Dk_2_4_23791 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# ------------------------------Processing video:------------------------------- Bqb2wT_eP_4
# Processing clip: 1
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 17
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_0_44023 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 69
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_0_43951 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_0_44173 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_0_44281 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_0_44719 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 20
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_1_44509 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_1_44683 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 32
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_1_43987 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_1_44389 already exists, skipping.
# Processing emotion: Neutral , len: 0
# Processing person: 2
# Processing emotion: Anger , len: 8
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_2_44053 already exists, skipping.
# Processing emotion: Disgust , len: 8
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_2_44425 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 3
# Processing emotion: Anger , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_3_44575 already exists, skipping.
# Processing emotion: Disgust , len: 8
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_1_3_44053 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing clip: 2
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_2_0_45091 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 21
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_2_1_45091 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_2_1_45367 already exists, skipping.
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_2_1_45169 already exists, skipping.
# Processing emotion: Neutral , len: 0
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_2_2_45091 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_2_3_45211 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 16
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_2_3_45385 already exists, skipping.
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_2_3_45133 already exists, skipping.
# Processing clip: 3
# Processing person: 0
# Processing emotion: Anger , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_0_48525 already exists, skipping.
# Processing emotion: Disgust , len: 17
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_0_48303 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 12
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_0_48453 already exists, skipping.
# Processing emotion: Neutral , len: 14
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_0_48604 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 16
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_1_48405 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 20
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_1_48567 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_1_48675 already exists, skipping.
# Processing emotion: Surprise , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_1_48489 already exists, skipping.
# Processing emotion: Neutral , len: 2
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Bqb2wT_eP_4_3_1_48771 already exists, skipping.
# ------------------------------Processing video:------------------------------- Ul53TVUR4NM
# Processing clip: 11
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 10
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_0_73848 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_0_73830 already exists, skipping.
# Processing emotion: Surprise , len: 8
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_0_73710 already exists, skipping.
# Processing emotion: Neutral , len: 24
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_0_73866 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_0_74016 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 51
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_1_73746 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_1_73794 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_1_73920 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 22
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_1_73920 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_1_74028 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_2_73758 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 24
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_2_73866 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_2_74016 already exists, skipping.
# Processing person: 3
# Processing emotion: Anger , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_3_74131 already exists, skipping.
# Processing emotion: Disgust , len: 10
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_3_74052 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_3_74166 already exists, skipping.
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 8
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_4_74082 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 12
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_4_74131 already exists, skipping.
# Processing person: 5
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 10
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_5_74166 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 4
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_5_74202 already exists, skipping.
# Processing person: 7
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 4
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_7_74202 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 6
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 4
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_11_6_74202 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing clip: 9
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 34
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35160 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35268 already exists, skipping.
# Processing emotion: Happy , len: 62
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35556 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35664 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35772 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35880 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 95
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35160 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35268 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35772 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35880 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_35988 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_0_36096 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 32
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_2_35160 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_2_35268 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 56
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_1_35160 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_1_35268 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_1_35376 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_1_35484 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 3
# Processing emotion: Anger , len: 74
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35304 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35412 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35520 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35628 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35736 already exists, skipping.
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 37
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35556 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35664 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35922 already exists, skipping.
# Processing emotion: Sad , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_36090 already exists, skipping.
# Processing emotion: Surprise , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_3_35952 already exists, skipping.
# Processing emotion: Neutral , len: 0
# Processing person: 5
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 4
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_5_35928 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 4
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_9_4_35928 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing clip: 10
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 154
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63001 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63199 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63475 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63487 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63595 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63595 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63763 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63907 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_64015 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 29
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63127 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_0_63715 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 17
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63235 already exists, skipping.
# Processing emotion: Disgust , len: 11
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63715 already exists, skipping.
# Processing emotion: Fear , len: 11
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63505 already exists, skipping.
# Processing emotion: Happy , len: 46
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63157 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63679 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63847 already exists, skipping.
# Processing emotion: Sad , len: 18
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63019 already exists, skipping.
# Processing emotion: Surprise , len: 31
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63097 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63487 already exists, skipping.
# Processing emotion: Neutral , len: 38
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_63019 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_64003 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_1_64057 already exists, skipping.
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 85
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_3_63037 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_3_63175 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_3_63433 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_3_63589 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_3_63823 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 37
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_3_63355 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_3_63709 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_3_64063 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 4
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_2_63211 already exists, skipping.
# Processing emotion: Happy , len: 89
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_2_63037 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_2_63337 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_2_63415 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_2_63571 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_2_63913 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 24
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_2_63655 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_2_64033 already exists, skipping.
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 10
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_4_63715 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 30
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_4_63127 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_10_4_63931 already exists, skipping.
# Processing clip: 8
# Processing person: 0
# Processing emotion: Anger , len: 43
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34757 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34865 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34973 already exists, skipping.
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 11
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34583 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 90
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34349 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34457 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34427 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34799 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_0_34907 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 26
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_1_34373 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_1_34481 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 45
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_1_34487 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_1_34595 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_1_34703 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 43
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_2_34757 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_2_34865 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_2_34973 already exists, skipping.
# Processing emotion: Disgust , len: 11
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_2_34649 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 14
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_3_34715 already exists, skipping.
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 14
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_4_34715 already exists, skipping.
# Processing person: 5
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 36
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_5_34757 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_5_34907 already exists, skipping.
# Processing person: 6
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_8_6_34805 already exists, skipping.
# Processing clip: 4
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_4_0_15121 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_4_0_15211 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 22
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_4_1_15121 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_4_1_15229 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 9
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_4_2_15253 already exists, skipping.
# Processing clip: 3
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 30
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_11923 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_12115 already exists, skipping.
# Processing emotion: Happy , len: 105
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_11371 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_11575 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_11545 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_11893 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_11905 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_12145 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_0_11569 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 95
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_11377 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_11485 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_11671 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_12229 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_12301 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_12427 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 86
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_11569 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_11677 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_11785 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_11845 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_1_12013 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 27
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_2_11377 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_2_12127 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_3_11479 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 21
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_4_11569 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_4_11941 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 7
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 3
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_7_12439 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_7_11755 already exists, skipping.
# Processing person: 5
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_5_11755 already exists, skipping.
# Processing person: 6
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_6_11755 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 8
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 5
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_8_11755 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 9
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 27
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_9_11959 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_9_12349 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 10
# Processing emotion: Anger , len: 16
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_10_11959 already exists, skipping.
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 11
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_10_12337 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 11
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 21
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_11_12055 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_11_12163 already exists, skipping.
# Processing person: 12
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 3
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_3_12_12439 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing clip: 5
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 20
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_0_16308 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_0_16674 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 28
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_0_15390 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_0_15696 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_1_15390 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_2_15390 already exists, skipping.
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_3_15390 already exists, skipping.
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_4_15390 already exists, skipping.
# Processing person: 5
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 43
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_16398 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_16506 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_16614 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 110
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_15426 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_15534 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_15738 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_15846 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_15954 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_16062 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_5_16206 already exists, skipping.
# Processing person: 6
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_6_16218 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 7
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 15
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_5_7_16218 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing clip: 6
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_0_20004 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 108
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_0_19800 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_0_19824 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_0_19932 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_0_20040 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_0_20148 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_0_20256 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 14
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_2_19800 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 14
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_1_19800 already exists, skipping.
# Processing person: 3
# Processing emotion: Anger , len: 69
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_3_19884 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_3_19992 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_3_20232 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_3_20340 already exists, skipping.
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 31
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_3_19884 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_6_3_19992 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing clip: 7
# Processing person: 0
# Processing emotion: Anger , len: 98
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_7_0_24335 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_7_0_24575 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_7_0_24725 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Ul53TVUR4NM_7_0_24923 already exists, skipping.
# ...
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_6_13387 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_6_13729 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_6_13837 already exists, skipping.
# Processing person: 7
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 59
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_7_13459 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_7_13993 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_7_14581 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_7_16315 already exists, skipping.
# Processing person: 8
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 160
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_13459 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_13771 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_13993 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_14581 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_14749 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_14929 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_15037 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_15475 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_8_16249 already exists, skipping.
# Processing person: 9
# Processing emotion: Anger , len: 182
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_14030 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_14857 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_15241 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_15415 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_15601 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_15841 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_15973 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_16081 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_16189 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_16297 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_16405 already exists, skipping.
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 18
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_14233 already exists, skipping.
# Processing emotion: Neutral , len: 71
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_13549 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_13657 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_13933 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_9_14575 already exists, skipping.
# Processing person: 10
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 10
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_10_14677 already exists, skipping.
# Processing person: 11
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 10
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_11_14677 already exists, skipping.
# Processing person: 12
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_12_14677 already exists, skipping.
# Processing person: 13
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_13_14887 already exists, skipping.
# Processing person: 14
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 22
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_14_16213 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/Uh00UIl7-bo_1_14_16321 already exists, skipping.
# ------------------------------Processing video:------------------------------- ngITkMvWuq8
# Processing clip: 1
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 13
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_1_0_18391 already exists, skipping.
# Processing emotion: Neutral , len: 8
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_1_0_18283 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 9
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_1_1_18469 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 10
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_1_1_18331 already exists, skipping.
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing clip: 2
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 47
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_2_3_20011 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_2_3_20227 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_2_3_20377 already exists, skipping.
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 2
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_2_0_20011 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 52
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_2_1_20011 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_2_1_20173 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_2_1_20329 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 18
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_2_2_20011 already exists, skipping.
# Processing clip: 3
# Processing person: 0
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_20701 already exists, skipping.
# Processing emotion: Happy , len: 100
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_20983 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_21242 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_21349 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_21559 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_21961 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_22147 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 20
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_20851 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_0_22279 already exists, skipping.
# Processing person: 1
# Processing emotion: Anger , len: 23
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_1_20917 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_1_21145 already exists, skipping.
# Processing emotion: Disgust , len: 19
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_1_20737 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_1_20845 already exists, skipping.
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 13
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_1_22159 already exists, skipping.
# Processing person: 2
# Processing emotion: Anger , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_2_21025 already exists, skipping.
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 3
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_3_21025 already exists, skipping.
# Processing emotion: Neutral , len: 0
# Processing person: 4
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 7
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_4_21025 already exists, skipping.
# Processing emotion: Neutral , len: 0
# Processing person: 5
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_5_21067 already exists, skipping.
# Processing emotion: Neutral , len: 0
# Processing person: 6
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 0
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 6
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_6_21067 already exists, skipping.
# Processing person: 7
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 51
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_7_21583 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_7_21691 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_7_21931 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 17
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_7_21433 already exists, skipping.
# Processing person: 8
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 11
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_8_21769 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 9
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 9
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_9_22442 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 23
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_9_22159 already exists, skipping.
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_9_22321 already exists, skipping.
# Processing person: 10
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 8
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_10_22393 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing person: 11
# Processing emotion: Anger , len: 0
# Processing emotion: Disgust , len: 0
# Processing emotion: Fear , len: 0
# Processing emotion: Happy , len: 8
# Path /Users/poojakishore/Documents/Codes/CapitaSelecta/Frames/ngITkMvWuq8_3_11_22393 already exists, skipping.
# Processing emotion: Sad , len: 0
# Processing emotion: Surprise , len: 0
# Processing emotion: Neutral , len: 0
# Processing completed.

# %%
df = pd.DataFrame({'file_name':PATHS , 'label': EMOTIONS})
df.to_csv('./MainDataSaved.csv', index=False)

# %%
len(PATHS)
# Out:
# 591
